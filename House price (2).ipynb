# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("kcHouseData.csv")#Reading data on csv file which is uploaded to jupyter notebook

# %%
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.dtypes #displaying datatypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
house = df.drop(['id'], axis = 1) #dropping column id as I don't need it for my analysis
house.head(5)
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
house.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
floor = house['floors'].value_counts()#Checking how many flats on unique floors
floor.to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %%
import matplotlib.pyplot as plt #importing these libraries for boxplot and visualization
import seaborn as sns

# %%
#boxplot helps identify outliers and understand the dispersion of data - 
#here in this case price wrt. waterfront (coded either 0 - no waterfront or 1 - with waterfront)

bplot = sns.boxplot(y='price', x='waterfront', 
                 data=house, 
                 width=0.5,
                 palette="colorblind",
                 )

# %%
bplot = sns.boxplot(y='price', x='bedrooms', 
                 data=house, 
                 width=0.5,
                 palette="colorblind",
                 )#here I have a feeling that 33 bedrooms should actually be 3 bedrooms, but I am not sure how to deal with it

# %%
sns.regplot(x="sqft_above",y="price",data = house) #regression plot of dependent price vs independent attributes

# %%
sns.regplot(x="bedrooms",y="price",data = house)

# %%
sns.regplot(x="floors",y="price",data = house)

# %%
house.corr(method ='pearson')
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
#we see that price has high correlation with sqft_living. So, we fit a Linear regression model 
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
lm.fit(df[['sqft_living']],df['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import scipy.stats as stats

# %%
Yhat = lm.predict(df[['sqft_living']])

# %%
Yhat
# Out:
# array([287555.06702451, 677621.82640197, 172499.40418656, ...,
#        242655.29616092, 405416.96554144, 242655.29616092])

# %%
#fitting a multiple-regression line to predict price based on several other attributes
z = df[['floors','waterfront','lat','bedrooms','sqft_basement','view','bathrooms','sqft_living15','sqft_above','grade','sqft_living']]

# %%
lm.fit(z, df['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.predict(z)
# Out:
# array([283813.62600191, 661973.62600191, 306325.62600191, ...,
#        303893.62600191, 428245.62600191, 303701.62600191])

# %%
lm.score(z,df['price'])#R^2 calculation
# Out:
# 0.6577152299369833

# %%
x = df[['sqft_living']]
y = df['price']
lm.fit(x,y)
lm.score(x,y)
# Out:
# 0.49285321790379316

# %%
#we see that the R^2 value for multiple regression is more than linear regression
#as per what I understand, it means that the multiple regression predictions fit the data better than linear regression model

# %%
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]
pipe=Pipeline(Input)
pipe.fit(z,y)
ypipe=pipe.predict(z)
from sklearn.metrics import r2_score
r_squared = r2_score(ypipe,y)
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.6679783529298373

# %%
#using polynomial regression, improved R^2 but only fractionally

# %%
#diving the data into training and test data.

y_data = y
x_data = z

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])


#polynomial transfromation of z
pr=PolynomialFeatures(degree=2)
x_train_pr=pr.fit_transform(x_train)
x_test_pr=pr.fit_transform(x_test)

#linear regression model to train it
poly = LinearRegression()
poly.fit(x_train_pr, y_train)

#predicting for test data
yhat = poly.predict(x_test_pr)
yhat[0:5]

print("Predicted values:", yhat[0:4])
print("True values:", y_test[0:4].values)

#R^2 for training set
rtrain = poly.score(x_train_pr, y_train)

#R^2 for test set
rtest = poly.score(x_test_pr, y_test)

print("\n\nR^2 for training data: ",rtrain, "\nR^2 for test data: ",rtest)


#trying to eliminate the effect of multicollinearity in this data using Ridge regression
#so that predicted price is much near actal price
from sklearn.linear_model import Ridge
RigeModel = Ridge(alpha=0.1)

RigeModel.fit(x_train_pr, y_train)

YP = RigeModel.predict(x_test_pr)
print("\n\narray: ",YP[0:4])
print('test set :', y_test[0:4].values)

rRigeTest = RigeModel.score(x_test_pr, y_test)

rRigeTrain = RigeModel.score(x_train_pr, y_train)
print("\n\nR^2 for training data: ",rRigeTest, "\nR^2 for test data: ",rRigeTrain)
# Out:
# number of test samples : 2162
# number of training samples: 19451
# Predicted values: [591769.32293034 453004.35938358 569924.61706161 690412.52718163]
# True values: [ 459000.  445000. 1057000.  732350.]
#
#
# R^2 for training data:  0.7494125118406387
# R^2 for test data:  0.7585554082714407
#
#
# array:  [572378.01873301 488107.47369259 608667.53000787 679520.78292026]
# test set : [ 459000.  445000. 1057000.  732350.]
#
#
# R^2 for training data:  0.7474128582077175
# R^2 for test data:  0.7372691849247588

# %%
#however, in attempt to eliminate multicoliearity of attributs, the R^2 value suffered a decline.
